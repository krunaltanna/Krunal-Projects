# %% [markdown]
# ##### Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
from scipy.misc import imread, imresize
import datetime
import os
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.set_random_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('Project_data/val.csv').readlines())
batch_size = 10

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def generator(source_path, folder_list, batch_size):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = [x for x in range(0,x)] #create a list of image numbers you want to use for a particular video
    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(folder_list)//batch_size # calculate the number of batches
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,channel)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,classes)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    temp = imresize(image,(y,z))
                    temp = temp/127.5-1 #Normalize data
                    
                    batch_data[folder,idx,:,:,0] = (temp[:,:,0])#normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (temp[:,:,1])#normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (temp[:,:,2])#normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches

        if (len(folder_list) != batch_size*num_batches):
            print("Batch: ",num_batches+1,"Index:", batch_size)
            batch_size = len(folder_list) - (batch_size*num_batches)
            batch_data = np.zeros((batch_size,x,y,z,channel)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,classes)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    temp = imresize(image,(y,z))
                    temp = temp/127.5-1 #Normalize data
                    
                    batch_data[folder,idx,:,:,0] = (temp[:,:,0])
                    batch_data[folder,idx,:,:,1] = (temp[:,:,1])
                    batch_data[folder,idx,:,:,2] = (temp[:,:,2])
                   
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'Project_data/train'
val_path = 'Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
# Out:
# # training sequences = 663
# # validation sequences = 100

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %% [markdown]
# ###  Model 1 - Layers=4, BS = 10, Epoch = 50

# %%
batch_size = 10
x = 30 # # x is the number of images
y = 120 # width of the image
z = 120 # height of the image
classes = 5 #5 gestures 
channel = 3 #RGB
num_epochs = 50
print ('# epochs =', num_epochs)
# Out:
# # epochs = 50

# %%
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from keras.layers import Dropout
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam

#write your model here

# Model 1
# One input and output layer
# 4 Convolutional and max pooling layers to obtain the most important/informatic features
# 2 Dense layers followed by dropout

model_1 = Sequential()

model_1.add(Conv3D(8,kernel_size=(3,3,3), input_shape=(x,y,z,channel), padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling3D(pool_size=(2,2,2)))


model_1.add(Conv3D(16,kernel_size=(3,3,3), padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling3D(pool_size=(2,2,2)))


model_1.add(Conv3D(32,kernel_size=(3,3,3), padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling3D(pool_size=(2,2,2)))


model_1.add(Conv3D(64,kernel_size=(3,3,3), padding='same'))
model_1.add(BatchNormalization())
model_1.add(Activation('relu'))
model_1.add(MaxPooling3D(pool_size=(2,2,2)))


#Flatten Layers
model_1.add(Flatten())
model_1.add(Dense(1000, activation='relu'))
model_1.add(Dropout(0.5))

model_1.add(Dense(500, activation='relu'))
model_1.add(Dropout(0.5))

#softmax layer
model_1.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.Adam(lr=0.0001) #write your optimizer
model_1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model_1.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 30, 120, 120, 8)   656
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 120, 120, 8)   32
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 120, 120, 8)   0
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 15, 60, 60, 8)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 15, 60, 60, 16)    3472
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 60, 60, 16)    64
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 60, 60, 16)    0
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 7, 30, 30, 16)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 7, 30, 30, 32)     13856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 30, 30, 32)     128
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 30, 30, 32)     0
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 3, 15, 15, 32)     0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 3, 15, 15, 64)     55360
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 3, 15, 15, 64)     256
# _________________________________________________________________
# activation_4 (Activation)    (None, 3, 15, 15, 64)     0
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 1, 7, 7, 64)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000)              3137000
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               500500
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 500)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 2505
# =================================================================
# Total params: 3,713,829
# Trainable params: 3,713,589
# Non-trainable params: 240
# _________________________________________________________________
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history1 = model_1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path = Source path =  Project_data/train ; batch size = 10
# Epoch 1/50 Project_data/val ; batch size = 10
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 65/67 [============================>.] - ETA: 5s - loss: 2.4141 - categorical_accuracy: 0.2877Batch:  67 Index: 10
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:42: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 67/67 [==============================] - 183s 3s/step - loss: 2.3826 - categorical_accuracy: 0.2900 - val_loss: 1.1834 - val_categorical_accuracy: 0.4800
#
# Epoch 00001: saving model to model_init_2021-02-0717_51_58.051438/model-00001-2.39825-0.28959-1.18344-0.48000.h5
# Epoch 2/50
# 67/67 [==============================] - 24s 364ms/step - loss: 2.0272 - categorical_accuracy: 0.3483 - val_loss: 1.3642 - val_categorical_accuracy: 0.4300
#
# Epoch 00002: saving model to model_init_2021-02-0717_51_58.051438/model-00002-2.02719-0.34826-1.36416-0.43000.h5
# Epoch 3/50
# 67/67 [==============================] - 25s 369ms/step - loss: 1.9121 - categorical_accuracy: 0.3085 - val_loss: 1.1788 - val_categorical_accuracy: 0.4500
#
# Epoch 00003: saving model to model_init_2021-02-0717_51_58.051438/model-00003-1.91213-0.30846-1.17877-0.45000.h5
# Epoch 4/50
# 67/67 [==============================] - 25s 372ms/step - loss: 1.7799 - categorical_accuracy: 0.3333 - val_loss: 1.0345 - val_categorical_accuracy: 0.6500
#
# Epoch 00004: saving model to model_init_2021-02-0717_51_58.051438/model-00004-1.77993-0.33333-1.03446-0.65000.h5
# Epoch 5/50
# 67/67 [==============================] - 26s 393ms/step - loss: 1.4949 - categorical_accuracy: 0.4129 - val_loss: 1.0757 - val_categorical_accuracy: 0.5500
#
# Epoch 00005: saving model to model_init_2021-02-0717_51_58.051438/model-00005-1.49491-0.41294-1.07567-0.55000.h5
# Epoch 6/50
# 67/67 [==============================] - 26s 385ms/step - loss: 1.6121 - categorical_accuracy: 0.3483 - val_loss: 1.0740 - val_categorical_accuracy: 0.5700
#
# Epoch 00006: saving model to model_init_2021-02-0717_51_58.051438/model-00006-1.61207-0.34826-1.07399-0.57000.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 7/50
# 67/67 [==============================] - 24s 360ms/step - loss: 1.3786 - categorical_accuracy: 0.4279 - val_loss: 1.0769 - val_categorical_accuracy: 0.5800
#
# Epoch 00007: saving model to model_init_2021-02-0717_51_58.051438/model-00007-1.37856-0.42786-1.07687-0.58000.h5
# Epoch 8/50
# 67/67 [==============================] - 24s 352ms/step - loss: 1.3219 - categorical_accuracy: 0.4478 - val_loss: 0.9958 - val_categorical_accuracy: 0.6400
#
# Epoch 00008: saving model to model_init_2021-02-0717_51_58.051438/model-00008-1.32189-0.44776-0.99583-0.64000.h5
# Epoch 9/50
# 67/67 [==============================] - 25s 369ms/step - loss: 1.2225 - categorical_accuracy: 0.5224 - val_loss: 0.9732 - val_categorical_accuracy: 0.5800
#
# Epoch 00009: saving model to model_init_2021-02-0717_51_58.051438/model-00009-1.22251-0.52239-0.97319-0.58000.h5
# Epoch 10/50
# 67/67 [==============================] - 23s 350ms/step - loss: 1.2309 - categorical_accuracy: 0.4627 - val_loss: 0.9726 - val_categorical_accuracy: 0.6500
#
# Epoch 00010: saving model to model_init_2021-02-0717_51_58.051438/model-00010-1.23093-0.46269-0.97257-0.65000.h5
# Epoch 11/50
# 67/67 [==============================] - 24s 356ms/step - loss: 1.1884 - categorical_accuracy: 0.4776 - val_loss: 0.9111 - val_categorical_accuracy: 0.6600
#
# Epoch 00011: saving model to model_init_2021-02-0717_51_58.051438/model-00011-1.18843-0.47761-0.91108-0.66000.h5
# Epoch 12/50
# 67/67 [==============================] - 25s 366ms/step - loss: 1.0232 - categorical_accuracy: 0.5920 - val_loss: 0.8938 - val_categorical_accuracy: 0.6600
#
# Epoch 00012: saving model to model_init_2021-02-0717_51_58.051438/model-00012-1.02325-0.59204-0.89383-0.66000.h5
# Epoch 13/50
# 67/67 [==============================] - 24s 352ms/step - loss: 1.0292 - categorical_accuracy: 0.5771 - val_loss: 0.8594 - val_categorical_accuracy: 0.7200
#
# Epoch 00013: saving model to model_init_2021-02-0717_51_58.051438/model-00013-1.02923-0.57711-0.85937-0.72000.h5
# Epoch 14/50
# 67/67 [==============================] - 24s 364ms/step - loss: 1.1678 - categorical_accuracy: 0.5373 - val_loss: 0.8805 - val_categorical_accuracy: 0.6700
#
# Epoch 00014: saving model to model_init_2021-02-0717_51_58.051438/model-00014-1.16783-0.53731-0.88049-0.67000.h5
# Epoch 15/50
# 67/67 [==============================] - 25s 368ms/step - loss: 1.1097 - categorical_accuracy: 0.5522 - val_loss: 0.8561 - val_categorical_accuracy: 0.6700
#
# Epoch 00015: saving model to model_init_2021-02-0717_51_58.051438/model-00015-1.10968-0.55224-0.85614-0.67000.h5
# Epoch 16/50
# 67/67 [==============================] - 24s 355ms/step - loss: 1.0114 - categorical_accuracy: 0.6119 - val_loss: 0.8907 - val_categorical_accuracy: 0.6500
#
# Epoch 00016: saving model to model_init_2021-02-0717_51_58.051438/model-00016-1.01138-0.61194-0.89065-0.65000.h5
# Epoch 17/50
# 67/67 [==============================] - 24s 363ms/step - loss: 0.9231 - categorical_accuracy: 0.6517 - val_loss: 0.8417 - val_categorical_accuracy: 0.6900
#
# Epoch 00017: saving model to model_init_2021-02-0717_51_58.051438/model-00017-0.92310-0.65174-0.84165-0.69000.h5
# Epoch 18/50
# 67/67 [==============================] - 25s 374ms/step - loss: 1.0198 - categorical_accuracy: 0.5423 - val_loss: 0.8511 - val_categorical_accuracy: 0.7000
#
# Epoch 00018: saving model to model_init_2021-02-0717_51_58.051438/model-00018-1.01982-0.54229-0.85109-0.70000.h5
# Epoch 19/50
# 67/67 [==============================] - 26s 382ms/step - loss: 0.8293 - categorical_accuracy: 0.6567 - val_loss: 0.8781 - val_categorical_accuracy: 0.6300
#
# Epoch 00019: saving model to model_init_2021-02-0717_51_58.051438/model-00019-0.82932-0.65672-0.87808-0.63000.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 20/50
# 67/67 [==============================] - 23s 349ms/step - loss: 0.8758 - categorical_accuracy: 0.6318 - val_loss: 0.8098 - val_categorical_accuracy: 0.6700
#
# Epoch 00020: saving model to model_init_2021-02-0717_51_58.051438/model-00020-0.87575-0.63184-0.80982-0.67000.h5
# Epoch 21/50
# 67/67 [==============================] - 24s 361ms/step - loss: 0.8599 - categorical_accuracy: 0.6816 - val_loss: 0.7855 - val_categorical_accuracy: 0.7200
#
# Epoch 00021: saving model to model_init_2021-02-0717_51_58.051438/model-00021-0.85992-0.68159-0.78553-0.72000.h5
# Epoch 22/50
# 67/67 [==============================] - 23s 350ms/step - loss: 0.8897 - categorical_accuracy: 0.6667 - val_loss: 0.8015 - val_categorical_accuracy: 0.7100
#
# Epoch 00022: saving model to model_init_2021-02-0717_51_58.051438/model-00022-0.88970-0.66667-0.80145-0.71000.h5
# Epoch 23/50
# 67/67 [==============================] - 24s 364ms/step - loss: 0.8210 - categorical_accuracy: 0.6866 - val_loss: 0.7788 - val_categorical_accuracy: 0.7100
#
# Epoch 00023: saving model to model_init_2021-02-0717_51_58.051438/model-00023-0.82097-0.68657-0.77875-0.71000.h5
# Epoch 24/50
# 67/67 [==============================] - 24s 354ms/step - loss: 0.7156 - categorical_accuracy: 0.7164 - val_loss: 0.7477 - val_categorical_accuracy: 0.7600
#
# Epoch 00024: saving model to model_init_2021-02-0717_51_58.051438/model-00024-0.71557-0.71642-0.74765-0.76000.h5
# Epoch 25/50
# 67/67 [==============================] - 24s 359ms/step - loss: 0.7719 - categorical_accuracy: 0.6816 - val_loss: 0.7576 - val_categorical_accuracy: 0.7400
#
# Epoch 00025: saving model to model_init_2021-02-0717_51_58.051438/model-00025-0.77189-0.68159-0.75757-0.74000.h5
# Epoch 26/50
# 67/67 [==============================] - 23s 342ms/step - loss: 0.7667 - categorical_accuracy: 0.6667 - val_loss: 0.7683 - val_categorical_accuracy: 0.7700
#
# Epoch 00026: saving model to model_init_2021-02-0717_51_58.051438/model-00026-0.76674-0.66667-0.76826-0.77000.h5
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 27/50
# 67/67 [==============================] - 24s 359ms/step - loss: 0.7215 - categorical_accuracy: 0.7313 - val_loss: 0.7357 - val_categorical_accuracy: 0.7300
#
# Epoch 00027: saving model to model_init_2021-02-0717_51_58.051438/model-00027-0.72153-0.73134-0.73570-0.73000.h5
# Epoch 28/50
# 67/67 [==============================] - 25s 371ms/step - loss: 0.6650 - categorical_accuracy: 0.7612 - val_loss: 0.7216 - val_categorical_accuracy: 0.7600
#
# Epoch 00028: saving model to model_init_2021-02-0717_51_58.051438/model-00028-0.66496-0.76119-0.72162-0.76000.h5
# Epoch 29/50
# 67/67 [==============================] - 23s 350ms/step - loss: 0.7466 - categorical_accuracy: 0.7015 - val_loss: 0.7337 - val_categorical_accuracy: 0.7500
#
# Epoch 00029: saving model to model_init_2021-02-0717_51_58.051438/model-00029-0.74660-0.70149-0.73374-0.75000.h5
# Epoch 30/50
# 67/67 [==============================] - 25s 369ms/step - loss: 0.6749 - categorical_accuracy: 0.7413 - val_loss: 0.7335 - val_categorical_accuracy: 0.7600
#
# Epoch 00030: saving model to model_init_2021-02-0717_51_58.051438/model-00030-0.67488-0.74129-0.73351-0.76000.h5
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 31/50
# 67/67 [==============================] - 23s 338ms/step - loss: 0.6927 - categorical_accuracy: 0.7413 - val_loss: 0.7338 - val_categorical_accuracy: 0.7400
#
# Epoch 00031: saving model to model_init_2021-02-0717_51_58.051438/model-00031-0.69269-0.74129-0.73384-0.74000.h5
# Epoch 32/50
# 67/67 [==============================] - 24s 351ms/step - loss: 0.6813 - categorical_accuracy: 0.6965 - val_loss: 0.7466 - val_categorical_accuracy: 0.7600
#
# Epoch 00032: saving model to model_init_2021-02-0717_51_58.051438/model-00032-0.68126-0.69652-0.74660-0.76000.h5
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 33/50
# 67/67 [==============================] - 25s 369ms/step - loss: 0.6378 - categorical_accuracy: 0.7313 - val_loss: 0.7324 - val_categorical_accuracy: 0.7400
#
# Epoch 00033: saving model to model_init_2021-02-0717_51_58.051438/model-00033-0.63779-0.73134-0.73236-0.74000.h5
# Epoch 34/50
# 67/67 [==============================] - 23s 349ms/step - loss: 0.6435 - categorical_accuracy: 0.7114 - val_loss: 0.7225 - val_categorical_accuracy: 0.7500
#
# Epoch 00034: saving model to model_init_2021-02-0717_51_58.051438/model-00034-0.64352-0.71144-0.72246-0.75000.h5
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 35/50
# 67/67 [==============================] - 24s 361ms/step - loss: 0.7070 - categorical_accuracy: 0.7811 - val_loss: 0.7254 - val_categorical_accuracy: 0.7600
#
# Epoch 00035: saving model to model_init_2021-02-0717_51_58.051438/model-00035-0.70704-0.78109-0.72535-0.76000.h5
# Epoch 36/50
# 67/67 [==============================] - 24s 356ms/step - loss: 0.5776 - categorical_accuracy: 0.7910 - val_loss: 0.7205 - val_categorical_accuracy: 0.7700
#
# Epoch 00036: saving model to model_init_2021-02-0717_51_58.051438/model-00036-0.57759-0.79104-0.72047-0.77000.h5
# Epoch 37/50
# 67/67 [==============================] - 24s 353ms/step - loss: 0.5978 - categorical_accuracy: 0.7512 - val_loss: 0.7232 - val_categorical_accuracy: 0.7500
#
# Epoch 00037: saving model to model_init_2021-02-0717_51_58.051438/model-00037-0.59783-0.75124-0.72317-0.75000.h5
# Epoch 38/50
# 67/67 [==============================] - 25s 367ms/step - loss: 0.6486 - categorical_accuracy: 0.7512 - val_loss: 0.7243 - val_categorical_accuracy: 0.7400
#
# Epoch 00038: saving model to model_init_2021-02-0717_51_58.051438/model-00038-0.64863-0.75124-0.72434-0.74000.h5
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 39/50
# 67/67 [==============================] - 23s 350ms/step - loss: 0.5754 - categorical_accuracy: 0.7562 - val_loss: 0.7230 - val_categorical_accuracy: 0.7400
#
# Epoch 00039: saving model to model_init_2021-02-0717_51_58.051438/model-00039-0.57544-0.75622-0.72300-0.74000.h5
# Epoch 40/50
# 67/67 [==============================] - 23s 346ms/step - loss: 0.6389 - categorical_accuracy: 0.7512 - val_loss: 0.7219 - val_categorical_accuracy: 0.7500
#
# Epoch 00040: saving model to model_init_2021-02-0717_51_58.051438/model-00040-0.63885-0.75124-0.72186-0.75000.h5
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 41/50
# 67/67 [==============================] - 23s 347ms/step - loss: 0.5923 - categorical_accuracy: 0.7662 - val_loss: 0.7233 - val_categorical_accuracy: 0.7300
#
# Epoch 00041: saving model to model_init_2021-02-0717_51_58.051438/model-00041-0.59229-0.76617-0.72328-0.73000.h5
# Epoch 42/50
# 67/67 [==============================] - 25s 368ms/step - loss: 0.5896 - categorical_accuracy: 0.7861 - val_loss: 0.7232 - val_categorical_accuracy: 0.7400
#
# Epoch 00042: saving model to model_init_2021-02-0717_51_58.051438/model-00042-0.58955-0.78607-0.72316-0.74000.h5
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 43/50
# 67/67 [==============================] - 23s 340ms/step - loss: 0.6426 - categorical_accuracy: 0.7711 - val_loss: 0.7222 - val_categorical_accuracy: 0.7400
#
# Epoch 00043: saving model to model_init_2021-02-0717_51_58.051438/model-00043-0.64257-0.77114-0.72218-0.74000.h5
# Epoch 44/50
# 67/67 [==============================] - 24s 354ms/step - loss: 0.6219 - categorical_accuracy: 0.7562 - val_loss: 0.7239 - val_categorical_accuracy: 0.7300
#
# Epoch 00044: saving model to model_init_2021-02-0717_51_58.051438/model-00044-0.62187-0.75622-0.72392-0.73000.h5
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Epoch 45/50
# 67/67 [==============================] - 23s 339ms/step - loss: 0.6142 - categorical_accuracy: 0.7910 - val_loss: 0.7248 - val_categorical_accuracy: 0.7300
#
# Epoch 00045: saving model to model_init_2021-02-0717_51_58.051438/model-00045-0.61419-0.79104-0.72480-0.73000.h5
# Epoch 46/50
# 67/67 [==============================] - 24s 356ms/step - loss: 0.6036 - categorical_accuracy: 0.7463 - val_loss: 0.7237 - val_categorical_accuracy: 0.7300
#
# Epoch 00046: saving model to model_init_2021-02-0717_51_58.051438/model-00046-0.60355-0.74627-0.72375-0.73000.h5
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# Epoch 47/50
# 67/67 [==============================] - 25s 369ms/step - loss: 0.6406 - categorical_accuracy: 0.7711 - val_loss: 0.7241 - val_categorical_accuracy: 0.7300
#
# Epoch 00047: saving model to model_init_2021-02-0717_51_58.051438/model-00047-0.64062-0.77114-0.72406-0.73000.h5
# Epoch 48/50
# 67/67 [==============================] - 22s 335ms/step - loss: 0.6515 - categorical_accuracy: 0.7114 - val_loss: 0.7295 - val_categorical_accuracy: 0.7500
#
# Epoch 00048: saving model to model_init_2021-02-0717_51_58.051438/model-00048-0.65149-0.71144-0.72952-0.75000.h5
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# Epoch 49/50
# 67/67 [==============================] - 25s 377ms/step - loss: 0.6261 - categorical_accuracy: 0.7214 - val_loss: 0.7238 - val_categorical_accuracy: 0.7300
#
# Epoch 00049: saving model to model_init_2021-02-0717_51_58.051438/model-00049-0.62614-0.72139-0.72384-0.73000.h5
# Epoch 50/50
# 67/67 [==============================] - 24s 364ms/step - loss: 0.6212 - categorical_accuracy: 0.7711 - val_loss: 0.7180 - val_categorical_accuracy: 0.7300
#
# Epoch 00050: saving model to model_init_2021-02-0717_51_58.051438/model-00050-0.62122-0.77114-0.71803-0.73000.h5

# %% [markdown]
# ### Model 2 - Layers=4, BS = 30, Epoch = 50

# %%
batch_size = 30
num_epochs = 50

train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

optimiser = optimizers.Adam(lr=0.0001) #write your optimizer
model_1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

history1_2 = model_1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  Project_data/val ; batch size = 30
# Source path =  Project_data/train ; batch size = 30
# Epoch 1/50
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#  3/67 [>.............................] - ETA: 4:56 - loss: 0.7331 - categorical_accuracy: 0.6778Batch:  4 Index: 30
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:42: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 21/67 [========>.....................] - ETA: 2:46 - loss: 0.6118 - categorical_accuracy: 0.7587Batch:  23 Index: 30
# 67/67 [==============================] - 96s 1s/step - loss: 0.7851 - categorical_accuracy: 0.6819 - val_loss: 0.9531 - val_categorical_accuracy: 0.6500
#
# Epoch 00001: saving model to model_init_2021-02-0717_51_58.051438/model-00001-0.65798-0.73711-0.95313-0.65000.h5
# Epoch 2/50
# 67/67 [==============================] - 26s 386ms/step - loss: 0.9489 - categorical_accuracy: 0.6567 - val_loss: 0.9422 - val_categorical_accuracy: 0.6500
#
# Epoch 00002: saving model to model_init_2021-02-0717_51_58.051438/model-00002-0.94894-0.65672-0.94217-0.65000.h5
# Epoch 3/50
# 67/67 [==============================] - 24s 365ms/step - loss: 0.8573 - categorical_accuracy: 0.6517 - val_loss: 0.7505 - val_categorical_accuracy: 0.6800
#
# Epoch 00003: saving model to model_init_2021-02-0717_51_58.051438/model-00003-0.85729-0.65174-0.75049-0.68000.h5
# Epoch 4/50
# 67/67 [==============================] - 25s 376ms/step - loss: 0.9036 - categorical_accuracy: 0.6766 - val_loss: 0.6711 - val_categorical_accuracy: 0.7500
#
# Epoch 00004: saving model to model_init_2021-02-0717_51_58.051438/model-00004-0.90358-0.67662-0.67107-0.75000.h5
# Epoch 5/50
# 67/67 [==============================] - 25s 377ms/step - loss: 0.7795 - categorical_accuracy: 0.7264 - val_loss: 0.6771 - val_categorical_accuracy: 0.7500
#
# Epoch 00005: saving model to model_init_2021-02-0717_51_58.051438/model-00005-0.77951-0.72637-0.67707-0.75000.h5
# Epoch 6/50
# 67/67 [==============================] - 25s 370ms/step - loss: 0.7381 - categorical_accuracy: 0.6915 - val_loss: 1.1709 - val_categorical_accuracy: 0.5200
#
# Epoch 00006: saving model to model_init_2021-02-0717_51_58.051438/model-00006-0.73810-0.69154-1.17090-0.52000.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 7/50
# 67/67 [==============================] - 25s 380ms/step - loss: 0.6663 - categorical_accuracy: 0.7612 - val_loss: 0.7105 - val_categorical_accuracy: 0.7800
#
# Epoch 00007: saving model to model_init_2021-02-0717_51_58.051438/model-00007-0.66628-0.76119-0.71053-0.78000.h5
# Epoch 8/50
# 67/67 [==============================] - 26s 395ms/step - loss: 0.4994 - categorical_accuracy: 0.8159 - val_loss: 0.6784 - val_categorical_accuracy: 0.7100
#
# Epoch 00008: saving model to model_init_2021-02-0717_51_58.051438/model-00008-0.49937-0.81592-0.67839-0.71000.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 9/50
# 67/67 [==============================] - 24s 357ms/step - loss: 0.4950 - categorical_accuracy: 0.8010 - val_loss: 0.5136 - val_categorical_accuracy: 0.8100
#
# Epoch 00009: saving model to model_init_2021-02-0717_51_58.051438/model-00009-0.49503-0.80100-0.51356-0.81000.h5
# Epoch 10/50
# 67/67 [==============================] - 26s 389ms/step - loss: 0.5949 - categorical_accuracy: 0.7512 - val_loss: 0.5960 - val_categorical_accuracy: 0.7300
#
# Epoch 00010: saving model to model_init_2021-02-0717_51_58.051438/model-00010-0.59493-0.75124-0.59597-0.73000.h5
# Epoch 11/50
# 67/67 [==============================] - 23s 351ms/step - loss: 0.5196 - categorical_accuracy: 0.7811 - val_loss: 0.7308 - val_categorical_accuracy: 0.7500
#
# Epoch 00011: saving model to model_init_2021-02-0717_51_58.051438/model-00011-0.51962-0.78109-0.73076-0.75000.h5
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 12/50
# 67/67 [==============================] - 25s 371ms/step - loss: 0.3556 - categorical_accuracy: 0.8706 - val_loss: 0.6901 - val_categorical_accuracy: 0.7500
#
# Epoch 00012: saving model to model_init_2021-02-0717_51_58.051438/model-00012-0.35564-0.87065-0.69015-0.75000.h5
# Epoch 13/50
# 67/67 [==============================] - 26s 393ms/step - loss: 0.4512 - categorical_accuracy: 0.8308 - val_loss: 0.5995 - val_categorical_accuracy: 0.8100
#
# Epoch 00013: saving model to model_init_2021-02-0717_51_58.051438/model-00013-0.45122-0.83085-0.59952-0.81000.h5
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 14/50
# 67/67 [==============================] - 25s 374ms/step - loss: 0.4533 - categorical_accuracy: 0.8259 - val_loss: 0.5880 - val_categorical_accuracy: 0.7800
#
# Epoch 00014: saving model to model_init_2021-02-0717_51_58.051438/model-00014-0.45333-0.82587-0.58797-0.78000.h5
# Epoch 15/50
# 67/67 [==============================] - 26s 386ms/step - loss: 0.4089 - categorical_accuracy: 0.8607 - val_loss: 0.6536 - val_categorical_accuracy: 0.7300
#
# Epoch 00015: saving model to model_init_2021-02-0717_51_58.051438/model-00015-0.40893-0.86070-0.65356-0.73000.h5
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 16/50
# 67/67 [==============================] - 26s 386ms/step - loss: 0.4350 - categorical_accuracy: 0.8458 - val_loss: 0.5489 - val_categorical_accuracy: 0.8300
#
# Epoch 00016: saving model to model_init_2021-02-0717_51_58.051438/model-00016-0.43504-0.84577-0.54886-0.83000.h5
# Epoch 17/50
# 67/67 [==============================] - 26s 385ms/step - loss: 0.4112 - categorical_accuracy: 0.8159 - val_loss: 0.6333 - val_categorical_accuracy: 0.7900
#
# Epoch 00017: saving model to model_init_2021-02-0717_51_58.051438/model-00017-0.41116-0.81592-0.63329-0.79000.h5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 18/50
# 67/67 [==============================] - 25s 372ms/step - loss: 0.3286 - categorical_accuracy: 0.8706 - val_loss: 0.5886 - val_categorical_accuracy: 0.7800
#
# Epoch 00018: saving model to model_init_2021-02-0717_51_58.051438/model-00018-0.32858-0.87065-0.58860-0.78000.h5
# Epoch 19/50
# 67/67 [==============================] - 25s 380ms/step - loss: 0.4733 - categorical_accuracy: 0.8060 - val_loss: 0.6130 - val_categorical_accuracy: 0.7900
#
# Epoch 00019: saving model to model_init_2021-02-0717_51_58.051438/model-00019-0.47329-0.80597-0.61302-0.79000.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 20/50
# 67/67 [==============================] - 25s 379ms/step - loss: 0.4214 - categorical_accuracy: 0.8607 - val_loss: 0.5667 - val_categorical_accuracy: 0.8100
#
# Epoch 00020: saving model to model_init_2021-02-0717_51_58.051438/model-00020-0.42135-0.86070-0.56674-0.81000.h5
# Epoch 21/50
# 67/67 [==============================] - 27s 402ms/step - loss: 0.3923 - categorical_accuracy: 0.8607 - val_loss: 0.6083 - val_categorical_accuracy: 0.7800
#
# Epoch 00021: saving model to model_init_2021-02-0717_51_58.051438/model-00021-0.39230-0.86070-0.60829-0.78000.h5
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 22/50
# 67/67 [==============================] - 24s 363ms/step - loss: 0.4567 - categorical_accuracy: 0.8458 - val_loss: 0.6597 - val_categorical_accuracy: 0.7600
#
# Epoch 00022: saving model to model_init_2021-02-0717_51_58.051438/model-00022-0.45672-0.84577-0.65969-0.76000.h5
# Epoch 23/50
# 67/67 [==============================] - 25s 378ms/step - loss: 0.3748 - categorical_accuracy: 0.8557 - val_loss: 0.5715 - val_categorical_accuracy: 0.7900
#
# Epoch 00023: saving model to model_init_2021-02-0717_51_58.051438/model-00023-0.37484-0.85572-0.57148-0.79000.h5
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 24/50
# 67/67 [==============================] - 26s 388ms/step - loss: 0.3594 - categorical_accuracy: 0.8557 - val_loss: 0.6869 - val_categorical_accuracy: 0.7500
#
# Epoch 00024: saving model to model_init_2021-02-0717_51_58.051438/model-00024-0.35938-0.85572-0.68694-0.75000.h5
# Epoch 25/50
# 67/67 [==============================] - 26s 392ms/step - loss: 0.3741 - categorical_accuracy: 0.8507 - val_loss: 0.5523 - val_categorical_accuracy: 0.8000
#
# Epoch 00025: saving model to model_init_2021-02-0717_51_58.051438/model-00025-0.37410-0.85075-0.55230-0.80000.h5
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Epoch 26/50
# 67/67 [==============================] - 25s 366ms/step - loss: 0.3982 - categorical_accuracy: 0.8458 - val_loss: 0.6066 - val_categorical_accuracy: 0.8100
#
# Epoch 00026: saving model to model_init_2021-02-0717_51_58.051438/model-00026-0.39821-0.84577-0.60664-0.81000.h5
# Epoch 27/50
# 67/67 [==============================] - 25s 375ms/step - loss: 0.4294 - categorical_accuracy: 0.8308 - val_loss: 0.5261 - val_categorical_accuracy: 0.8200
#
# Epoch 00027: saving model to model_init_2021-02-0717_51_58.051438/model-00027-0.42942-0.83085-0.52615-0.82000.h5
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# Epoch 28/50
# 67/67 [==============================] - 25s 379ms/step - loss: 0.4058 - categorical_accuracy: 0.8507 - val_loss: 0.7279 - val_categorical_accuracy: 0.7200
#
# Epoch 00028: saving model to model_init_2021-02-0717_51_58.051438/model-00028-0.40584-0.85075-0.72791-0.72000.h5
# Epoch 29/50
# 67/67 [==============================] - 25s 369ms/step - loss: 0.4444 - categorical_accuracy: 0.8109 - val_loss: 0.5927 - val_categorical_accuracy: 0.8100
#
# Epoch 00029: saving model to model_init_2021-02-0717_51_58.051438/model-00029-0.44440-0.81095-0.59269-0.81000.h5
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# Epoch 30/50
# 67/67 [==============================] - 26s 395ms/step - loss: 0.3402 - categorical_accuracy: 0.8905 - val_loss: 0.6210 - val_categorical_accuracy: 0.7600
#
# Epoch 00030: saving model to model_init_2021-02-0717_51_58.051438/model-00030-0.34020-0.89055-0.62100-0.76000.h5
# Epoch 31/50
# 67/67 [==============================] - 25s 375ms/step - loss: 0.3974 - categorical_accuracy: 0.8557 - val_loss: 0.5590 - val_categorical_accuracy: 0.7900
#
# Epoch 00031: saving model to model_init_2021-02-0717_51_58.051438/model-00031-0.39744-0.85572-0.55901-0.79000.h5
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
# Epoch 32/50
# 67/67 [==============================] - 25s 374ms/step - loss: 0.4009 - categorical_accuracy: 0.8607 - val_loss: 0.5997 - val_categorical_accuracy: 0.8000
#
# Epoch 00032: saving model to model_init_2021-02-0717_51_58.051438/model-00032-0.40093-0.86070-0.59971-0.80000.h5
# Epoch 33/50
# 67/67 [==============================] - 26s 383ms/step - loss: 0.3423 - categorical_accuracy: 0.8706 - val_loss: 0.5771 - val_categorical_accuracy: 0.8000
#
# Epoch 00033: saving model to model_init_2021-02-0717_51_58.051438/model-00033-0.34229-0.87065-0.57715-0.80000.h5
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 6.103515470812226e-09.
# Epoch 34/50
# 67/67 [==============================] - 27s 405ms/step - loss: 0.3994 - categorical_accuracy: 0.8657 - val_loss: 0.5884 - val_categorical_accuracy: 0.8000
#
# Epoch 00034: saving model to model_init_2021-02-0717_51_58.051438/model-00034-0.39942-0.86567-0.58841-0.80000.h5
# Epoch 35/50
# 67/67 [==============================] - 26s 384ms/step - loss: 0.3888 - categorical_accuracy: 0.8507 - val_loss: 0.7128 - val_categorical_accuracy: 0.7200
#
# Epoch 00035: saving model to model_init_2021-02-0717_51_58.051438/model-00035-0.38881-0.85075-0.71277-0.72000.h5
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.051757735406113e-09.
# Epoch 36/50
# 67/67 [==============================] - 24s 361ms/step - loss: 0.4198 - categorical_accuracy: 0.8408 - val_loss: 0.4877 - val_categorical_accuracy: 0.8500
#
# Epoch 00036: saving model to model_init_2021-02-0717_51_58.051438/model-00036-0.41980-0.84080-0.48767-0.85000.h5
# Epoch 37/50
# 67/67 [==============================] - 25s 369ms/step - loss: 0.3754 - categorical_accuracy: 0.8806 - val_loss: 0.6276 - val_categorical_accuracy: 0.7500
#
# Epoch 00037: saving model to model_init_2021-02-0717_51_58.051438/model-00037-0.37536-0.88060-0.62761-0.75000.h5
# Epoch 38/50
# 67/67 [==============================] - 26s 390ms/step - loss: 0.4625 - categorical_accuracy: 0.8308 - val_loss: 0.6366 - val_categorical_accuracy: 0.7600
#
# Epoch 00038: saving model to model_init_2021-02-0717_51_58.051438/model-00038-0.46249-0.83085-0.63663-0.76000.h5
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.5258788677030566e-09.
# Epoch 39/50
# 67/67 [==============================] - 25s 377ms/step - loss: 0.3386 - categorical_accuracy: 0.8756 - val_loss: 0.6475 - val_categorical_accuracy: 0.7500
#
# Epoch 00039: saving model to model_init_2021-02-0717_51_58.051438/model-00039-0.33858-0.87562-0.64748-0.75000.h5
# Epoch 40/50
# 67/67 [==============================] - 25s 367ms/step - loss: 0.3970 - categorical_accuracy: 0.8607 - val_loss: 0.5735 - val_categorical_accuracy: 0.8200
#
# Epoch 00040: saving model to model_init_2021-02-0717_51_58.051438/model-00040-0.39704-0.86070-0.57353-0.82000.h5
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 7.629394338515283e-10.
# Epoch 41/50
# 67/67 [==============================] - 26s 392ms/step - loss: 0.3823 - categorical_accuracy: 0.8607 - val_loss: 0.7002 - val_categorical_accuracy: 0.7200
#
# Epoch 00041: saving model to model_init_2021-02-0717_51_58.051438/model-00041-0.38231-0.86070-0.70024-0.72000.h5
# Epoch 42/50
# 67/67 [==============================] - 25s 375ms/step - loss: 0.3568 - categorical_accuracy: 0.8806 - val_loss: 0.4902 - val_categorical_accuracy: 0.8200
#
# Epoch 00042: saving model to model_init_2021-02-0717_51_58.051438/model-00042-0.35679-0.88060-0.49017-0.82000.h5
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 3.8146971692576415e-10.
# Epoch 43/50
# 67/67 [==============================] - 25s 374ms/step - loss: 0.4292 - categorical_accuracy: 0.8408 - val_loss: 0.6059 - val_categorical_accuracy: 0.8000
#
# Epoch 00043: saving model to model_init_2021-02-0717_51_58.051438/model-00043-0.42922-0.84080-0.60585-0.80000.h5
# Epoch 44/50
# 67/67 [==============================] - 28s 411ms/step - loss: 0.4628 - categorical_accuracy: 0.8308 - val_loss: 0.6533 - val_categorical_accuracy: 0.7500
#
# Epoch 00044: saving model to model_init_2021-02-0717_51_58.051438/model-00044-0.46279-0.83085-0.65333-0.75000.h5
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.9073485846288207e-10.
# Epoch 45/50
# 67/67 [==============================] - 30s 443ms/step - loss: 0.4663 - categorical_accuracy: 0.7662 - val_loss: 0.6898 - val_categorical_accuracy: 0.7500
#
# Epoch 00045: saving model to model_init_2021-02-0717_51_58.051438/model-00045-0.46626-0.76617-0.68983-0.75000.h5
# Epoch 46/50
# 67/67 [==============================] - 32s 475ms/step - loss: 0.4143 - categorical_accuracy: 0.8358 - val_loss: 0.5798 - val_categorical_accuracy: 0.8000
#
# Epoch 00046: saving model to model_init_2021-02-0717_51_58.051438/model-00046-0.41426-0.83582-0.57978-0.80000.h5
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 9.536742923144104e-11.
# Epoch 47/50
# 67/67 [==============================] - 27s 410ms/step - loss: 0.4159 - categorical_accuracy: 0.8756 - val_loss: 0.4885 - val_categorical_accuracy: 0.8300
#
# Epoch 00047: saving model to model_init_2021-02-0717_51_58.051438/model-00047-0.41586-0.87562-0.48855-0.83000.h5
# Epoch 48/50
# 67/67 [==============================] - 27s 400ms/step - loss: 0.3282 - categorical_accuracy: 0.8756 - val_loss: 0.6387 - val_categorical_accuracy: 0.7900
#
# Epoch 00048: saving model to model_init_2021-02-0717_51_58.051438/model-00048-0.32820-0.87562-0.63868-0.79000.h5
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 4.768371461572052e-11.
# Epoch 49/50
# 67/67 [==============================] - 25s 367ms/step - loss: 0.3539 - categorical_accuracy: 0.9104 - val_loss: 0.5994 - val_categorical_accuracy: 0.7900
#
# Epoch 00049: saving model to model_init_2021-02-0717_51_58.051438/model-00049-0.35386-0.91045-0.59944-0.79000.h5
# Epoch 50/50
# 67/67 [==============================] - 25s 369ms/step - loss: 0.4079 - categorical_accuracy: 0.8706 - val_loss: 0.6465 - val_categorical_accuracy: 0.7400
#
# Epoch 00050: saving model to model_init_2021-02-0717_51_58.051438/model-00050-0.40788-0.87065-0.64652-0.74000.h5
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 2.384185730786026e-11.

# %% [markdown]
# ### Model 3 - Layers=4, BS = 50, Epoch = 15

# %%
batch_size = 50
num_epochs = 15

train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

optimiser = optimizers.Adam(lr=0.0001) #write your optimizer
model_1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

history1_3 = model_1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  Project_data/val ; batch size = 50
# Source path =  Project_data/train ; batch size = 50
# Epoch 1/15
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 12/67 [====>.........................] - ETA: 6:48 - loss: 0.3090 - categorical_accuracy: 0.8983Batch:  14 Index: 50
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:42: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 67/67 [==============================] - 234s 3s/step - loss: 0.3577 - categorical_accuracy: 0.8619 - val_loss: 0.6201 - val_categorical_accuracy: 0.7600
#
# Epoch 00001: saving model to model_init_2021-02-0717_51_58.051438/model-00001-0.34206-0.87426-0.62010-0.76000.h5
# Epoch 2/15
# 67/67 [==============================] - 127s 2s/step - loss: 0.3150 - categorical_accuracy: 0.8840 - val_loss: 0.6682 - val_categorical_accuracy: 0.7500
#
# Epoch 00002: saving model to model_init_2021-02-0717_51_58.051438/model-00002-0.31500-0.88404-0.66822-0.75000.h5
# Epoch 3/15
# 67/67 [==============================] - 130s 2s/step - loss: 0.2684 - categorical_accuracy: 0.9059 - val_loss: 0.5679 - val_categorical_accuracy: 0.7500
#
# Epoch 00003: saving model to model_init_2021-02-0717_51_58.051438/model-00003-0.26839-0.90586-0.56792-0.75000.h5
# Epoch 4/15
# 67/67 [==============================] - 132s 2s/step - loss: 0.1927 - categorical_accuracy: 0.9380 - val_loss: 0.5567 - val_categorical_accuracy: 0.8100
#
# Epoch 00004: saving model to model_init_2021-02-0717_51_58.051438/model-00004-0.19271-0.93800-0.55672-0.81000.h5
# Epoch 5/15
# 67/67 [==============================] - 131s 2s/step - loss: 0.1425 - categorical_accuracy: 0.9564 - val_loss: 0.5432 - val_categorical_accuracy: 0.8100
#
# Epoch 00005: saving model to model_init_2021-02-0717_51_58.051438/model-00005-0.14254-0.95637-0.54321-0.81000.h5
# Epoch 6/15
# 67/67 [==============================] - 126s 2s/step - loss: 0.1290 - categorical_accuracy: 0.9541 - val_loss: 0.7116 - val_categorical_accuracy: 0.7900
#
# Epoch 00006: saving model to model_init_2021-02-0717_51_58.051438/model-00006-0.12898-0.95408-0.71159-0.79000.h5
# Epoch 7/15
# 67/67 [==============================] - 127s 2s/step - loss: 0.1126 - categorical_accuracy: 0.9575 - val_loss: 0.6199 - val_categorical_accuracy: 0.7600
#
# Epoch 00007: saving model to model_init_2021-02-0717_51_58.051438/model-00007-0.11257-0.95752-0.61995-0.76000.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 8/15
# 67/67 [==============================] - 128s 2s/step - loss: 0.0809 - categorical_accuracy: 0.9793 - val_loss: 0.5620 - val_categorical_accuracy: 0.7900
#
# Epoch 00008: saving model to model_init_2021-02-0717_51_58.051438/model-00008-0.08086-0.97933-0.56195-0.79000.h5
# Epoch 9/15
# 67/67 [==============================] - 133s 2s/step - loss: 0.0776 - categorical_accuracy: 0.9770 - val_loss: 0.6636 - val_categorical_accuracy: 0.8000
#
# Epoch 00009: saving model to model_init_2021-02-0717_51_58.051438/model-00009-0.07761-0.97704-0.66365-0.80000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 10/15
# 67/67 [==============================] - 126s 2s/step - loss: 0.0441 - categorical_accuracy: 0.9885 - val_loss: 0.5771 - val_categorical_accuracy: 0.8100
#
# Epoch 00010: saving model to model_init_2021-02-0717_51_58.051438/model-00010-0.04412-0.98852-0.57708-0.81000.h5
# Epoch 11/15
# 67/67 [==============================] - 131s 2s/step - loss: 0.0436 - categorical_accuracy: 0.9897 - val_loss: 0.6038 - val_categorical_accuracy: 0.8200
#
# Epoch 00011: saving model to model_init_2021-02-0717_51_58.051438/model-00011-0.04358-0.98967-0.60383-0.82000.h5
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 12/15
# 67/67 [==============================] - 132s 2s/step - loss: 0.0400 - categorical_accuracy: 0.9931 - val_loss: 0.6372 - val_categorical_accuracy: 0.8100
#
# Epoch 00012: saving model to model_init_2021-02-0717_51_58.051438/model-00012-0.04004-0.99311-0.63718-0.81000.h5
# Epoch 13/15
# 67/67 [==============================] - 121s 2s/step - loss: 0.0420 - categorical_accuracy: 0.9862 - val_loss: 0.6156 - val_categorical_accuracy: 0.8100
#
# Epoch 00013: saving model to model_init_2021-02-0717_51_58.051438/model-00013-0.04196-0.98622-0.61556-0.81000.h5
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 14/15
# 67/67 [==============================] - 127s 2s/step - loss: 0.0302 - categorical_accuracy: 0.9954 - val_loss: 0.6125 - val_categorical_accuracy: 0.8100
#
# Epoch 00014: saving model to model_init_2021-02-0717_51_58.051438/model-00014-0.03017-0.99541-0.61252-0.81000.h5
# Epoch 15/15
# 67/67 [==============================] - 129s 2s/step - loss: 0.0300 - categorical_accuracy: 0.9931 - val_loss: 0.6005 - val_categorical_accuracy: 0.8000
#
# Epoch 00015: saving model to model_init_2021-02-0717_51_58.051438/model-00015-0.03000-0.99311-0.60055-0.80000.h5
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.

# %% [markdown]
# ### Model 4 - Layers=4, BS = 30, Epoch = 50

# %%
batch_size = 30
num_epochs = 50

train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

optimiser = optimizers.Adam(lr=0.0001) #write your optimizer
model_1.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

history1_2 = model_1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  Project_data/val ; batch size = 30
# Source path =  Project_data/train ; batch size = 30
# Epoch 1/50
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#  3/67 [>.............................] - ETA: 5:18 - loss: 0.0523 - categorical_accuracy: 0.9778Batch:  4 Index: 30
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:42: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 21/67 [========>.....................] - ETA: 2:49 - loss: 0.0408 - categorical_accuracy: 0.9905Batch:  23 Index: 30
# 67/67 [==============================] - 96s 1s/step - loss: 0.1252 - categorical_accuracy: 0.9625 - val_loss: 0.8246 - val_categorical_accuracy: 0.7563
#
# Epoch 00001: saving model to model_init_2021-02-0717_51_58.051438/model-00001-0.06263-0.98365-0.82457-0.75625.h5
# Epoch 2/50
# 67/67 [==============================] - 24s 361ms/step - loss: 0.3188 - categorical_accuracy: 0.8955 - val_loss: 1.0213 - val_categorical_accuracy: 0.6700
#
# Epoch 00002: saving model to model_init_2021-02-0717_51_58.051438/model-00002-0.31875-0.89552-1.02134-0.67000.h5
# Epoch 3/50
# 67/67 [==============================] - 23s 349ms/step - loss: 0.3410 - categorical_accuracy: 0.8856 - val_loss: 1.3297 - val_categorical_accuracy: 0.6000
#
# Epoch 00003: saving model to model_init_2021-02-0717_51_58.051438/model-00003-0.34099-0.88557-1.32973-0.60000.h5
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 4/50
# 67/67 [==============================] - 24s 354ms/step - loss: 0.2779 - categorical_accuracy: 0.9055 - val_loss: 0.5818 - val_categorical_accuracy: 0.8200
#
# Epoch 00004: saving model to model_init_2021-02-0717_51_58.051438/model-00004-0.27792-0.90547-0.58180-0.82000.h5
# Epoch 5/50
# 67/67 [==============================] - 23s 345ms/step - loss: 0.1968 - categorical_accuracy: 0.9154 - val_loss: 0.7844 - val_categorical_accuracy: 0.7900
#
# Epoch 00005: saving model to model_init_2021-02-0717_51_58.051438/model-00005-0.19682-0.91542-0.78437-0.79000.h5
# Epoch 6/50
# 67/67 [==============================] - 23s 346ms/step - loss: 0.1518 - categorical_accuracy: 0.9502 - val_loss: 0.7234 - val_categorical_accuracy: 0.8200
#
# Epoch 00006: saving model to model_init_2021-02-0717_51_58.051438/model-00006-0.15183-0.95025-0.72342-0.82000.h5
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 7/50
# 67/67 [==============================] - 24s 365ms/step - loss: 0.1172 - categorical_accuracy: 0.9552 - val_loss: 0.9689 - val_categorical_accuracy: 0.7800
#
# Epoch 00007: saving model to model_init_2021-02-0717_51_58.051438/model-00007-0.11720-0.95522-0.96888-0.78000.h5
# Epoch 8/50
# 67/67 [==============================] - 24s 361ms/step - loss: 0.0852 - categorical_accuracy: 0.9701 - val_loss: 0.7050 - val_categorical_accuracy: 0.8100
#
# Epoch 00008: saving model to model_init_2021-02-0717_51_58.051438/model-00008-0.08519-0.97015-0.70502-0.81000.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 9/50
# 67/67 [==============================] - 23s 339ms/step - loss: 0.0891 - categorical_accuracy: 0.9552 - val_loss: 0.7323 - val_categorical_accuracy: 0.8100
#
# Epoch 00009: saving model to model_init_2021-02-0717_51_58.051438/model-00009-0.08909-0.95522-0.73233-0.81000.h5
# Epoch 10/50
# 67/67 [==============================] - 24s 351ms/step - loss: 0.0799 - categorical_accuracy: 0.9701 - val_loss: 0.8255 - val_categorical_accuracy: 0.7900
#
# Epoch 00010: saving model to model_init_2021-02-0717_51_58.051438/model-00010-0.07994-0.97015-0.82555-0.79000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 11/50
# 67/67 [==============================] - 24s 361ms/step - loss: 0.0845 - categorical_accuracy: 0.9701 - val_loss: 0.7595 - val_categorical_accuracy: 0.7600
#
# Epoch 00011: saving model to model_init_2021-02-0717_51_58.051438/model-00011-0.08455-0.97015-0.75948-0.76000.h5
# Epoch 12/50
# 67/67 [==============================] - 24s 355ms/step - loss: 0.0418 - categorical_accuracy: 0.9900 - val_loss: 0.7042 - val_categorical_accuracy: 0.7700
#
# Epoch 00012: saving model to model_init_2021-02-0717_51_58.051438/model-00012-0.04183-0.99005-0.70418-0.77000.h5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 13/50
# 67/67 [==============================] - 24s 363ms/step - loss: 0.0648 - categorical_accuracy: 0.9751 - val_loss: 0.7577 - val_categorical_accuracy: 0.7800
#
# Epoch 00013: saving model to model_init_2021-02-0717_51_58.051438/model-00013-0.06482-0.97512-0.75774-0.78000.h5
# Epoch 14/50
# 67/67 [==============================] - 24s 362ms/step - loss: 0.0513 - categorical_accuracy: 0.9851 - val_loss: 0.7222 - val_categorical_accuracy: 0.8000
#
# Epoch 00014: saving model to model_init_2021-02-0717_51_58.051438/model-00014-0.05134-0.98507-0.72224-0.80000.h5
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 15/50
# 67/67 [==============================] - 23s 349ms/step - loss: 0.0622 - categorical_accuracy: 0.9801 - val_loss: 0.7240 - val_categorical_accuracy: 0.7700
#
# Epoch 00015: saving model to model_init_2021-02-0717_51_58.051438/model-00015-0.06221-0.98010-0.72403-0.77000.h5
# Epoch 16/50
# 67/67 [==============================] - 23s 340ms/step - loss: 0.0488 - categorical_accuracy: 0.9900 - val_loss: 1.0789 - val_categorical_accuracy: 0.7200
#
# Epoch 00016: saving model to model_init_2021-02-0717_51_58.051438/model-00016-0.04879-0.99005-1.07893-0.72000.h5
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 17/50
# 67/67 [==============================] - 23s 346ms/step - loss: 0.0615 - categorical_accuracy: 0.9751 - val_loss: 0.5556 - val_categorical_accuracy: 0.8300
#
# Epoch 00017: saving model to model_init_2021-02-0717_51_58.051438/model-00017-0.06146-0.97512-0.55559-0.83000.h5
# Epoch 18/50
# 67/67 [==============================] - 23s 342ms/step - loss: 0.0610 - categorical_accuracy: 0.9751 - val_loss: 0.9084 - val_categorical_accuracy: 0.7600
#
# Epoch 00018: saving model to model_init_2021-02-0717_51_58.051438/model-00018-0.06100-0.97512-0.90839-0.76000.h5
# Epoch 19/50
# 67/67 [==============================] - 25s 370ms/step - loss: 0.0893 - categorical_accuracy: 0.9701 - val_loss: 0.6104 - val_categorical_accuracy: 0.8200
#
# Epoch 00019: saving model to model_init_2021-02-0717_51_58.051438/model-00019-0.08929-0.97015-0.61043-0.82000.h5
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 20/50
# 67/67 [==============================] - 23s 346ms/step - loss: 0.0550 - categorical_accuracy: 0.9751 - val_loss: 0.7854 - val_categorical_accuracy: 0.7500
#
# Epoch 00020: saving model to model_init_2021-02-0717_51_58.051438/model-00020-0.05502-0.97512-0.78538-0.75000.h5
# Epoch 21/50
# 67/67 [==============================] - 24s 352ms/step - loss: 0.0734 - categorical_accuracy: 0.9751 - val_loss: 0.7533 - val_categorical_accuracy: 0.7600
#
# Epoch 00021: saving model to model_init_2021-02-0717_51_58.051438/model-00021-0.07345-0.97512-0.75331-0.76000.h5
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 22/50
# 67/67 [==============================] - 24s 352ms/step - loss: 0.0713 - categorical_accuracy: 0.9701 - val_loss: 0.8379 - val_categorical_accuracy: 0.7700
#
# Epoch 00022: saving model to model_init_2021-02-0717_51_58.051438/model-00022-0.07127-0.97015-0.83791-0.77000.h5
# Epoch 23/50
# 67/67 [==============================] - 23s 349ms/step - loss: 0.0579 - categorical_accuracy: 0.9801 - val_loss: 0.8310 - val_categorical_accuracy: 0.7400
#
# Epoch 00023: saving model to model_init_2021-02-0717_51_58.051438/model-00023-0.05787-0.98010-0.83102-0.74000.h5
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Epoch 24/50
# 67/67 [==============================] - 24s 355ms/step - loss: 0.0487 - categorical_accuracy: 0.9950 - val_loss: 0.6841 - val_categorical_accuracy: 0.7800
#
# Epoch 00024: saving model to model_init_2021-02-0717_51_58.051438/model-00024-0.04871-0.99502-0.68405-0.78000.h5
# Epoch 25/50
# 67/67 [==============================] - 24s 355ms/step - loss: 0.0717 - categorical_accuracy: 0.9701 - val_loss: 0.6871 - val_categorical_accuracy: 0.8000
#
# Epoch 00025: saving model to model_init_2021-02-0717_51_58.051438/model-00025-0.07172-0.97015-0.68708-0.80000.h5
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# Epoch 26/50
# 67/67 [==============================] - 23s 344ms/step - loss: 0.0467 - categorical_accuracy: 0.9950 - val_loss: 0.8890 - val_categorical_accuracy: 0.7500
#
# Epoch 00026: saving model to model_init_2021-02-0717_51_58.051438/model-00026-0.04668-0.99502-0.88901-0.75000.h5
# Epoch 27/50
# 67/67 [==============================] - 23s 344ms/step - loss: 0.0593 - categorical_accuracy: 0.9851 - val_loss: 0.7506 - val_categorical_accuracy: 0.7800
#
# Epoch 00027: saving model to model_init_2021-02-0717_51_58.051438/model-00027-0.05927-0.98507-0.75057-0.78000.h5
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 2.4414061883248905e-08.
# Epoch 28/50
# 67/67 [==============================] - 23s 349ms/step - loss: 0.1057 - categorical_accuracy: 0.9602 - val_loss: 0.8600 - val_categorical_accuracy: 0.7700
#
# Epoch 00028: saving model to model_init_2021-02-0717_51_58.051438/model-00028-0.10566-0.96020-0.86004-0.77000.h5
# Epoch 29/50
# 67/67 [==============================] - 24s 353ms/step - loss: 0.0746 - categorical_accuracy: 0.9701 - val_loss: 0.5323 - val_categorical_accuracy: 0.8100
#
# Epoch 00029: saving model to model_init_2021-02-0717_51_58.051438/model-00029-0.07462-0.97015-0.53233-0.81000.h5
# Epoch 30/50
# 67/67 [==============================] - 23s 348ms/step - loss: 0.0884 - categorical_accuracy: 0.9751 - val_loss: 0.7328 - val_categorical_accuracy: 0.8000
#
# Epoch 00030: saving model to model_init_2021-02-0717_51_58.051438/model-00030-0.08841-0.97512-0.73283-0.80000.h5
# Epoch 31/50
# 67/67 [==============================] - 24s 354ms/step - loss: 0.0615 - categorical_accuracy: 0.9751 - val_loss: 0.9284 - val_categorical_accuracy: 0.7600
#
# Epoch 00031: saving model to model_init_2021-02-0717_51_58.051438/model-00031-0.06148-0.97512-0.92844-0.76000.h5
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.2207030941624453e-08.
# Epoch 32/50
# 67/67 [==============================] - 23s 340ms/step - loss: 0.0590 - categorical_accuracy: 0.9801 - val_loss: 0.7482 - val_categorical_accuracy: 0.7800
#
# Epoch 00032: saving model to model_init_2021-02-0717_51_58.051438/model-00032-0.05903-0.98010-0.74819-0.78000.h5
# Epoch 33/50
# 67/67 [==============================] - 24s 352ms/step - loss: 0.0641 - categorical_accuracy: 0.9801 - val_loss: 0.7967 - val_categorical_accuracy: 0.7800
#
# Epoch 00033: saving model to model_init_2021-02-0717_51_58.051438/model-00033-0.06407-0.98010-0.79669-0.78000.h5
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 6.103515470812226e-09.
# Epoch 34/50
# 67/67 [==============================] - 23s 346ms/step - loss: 0.0784 - categorical_accuracy: 0.9751 - val_loss: 0.7360 - val_categorical_accuracy: 0.7700
#
# Epoch 00034: saving model to model_init_2021-02-0717_51_58.051438/model-00034-0.07842-0.97512-0.73597-0.77000.h5
# Epoch 35/50
# 67/67 [==============================] - 23s 343ms/step - loss: 0.0596 - categorical_accuracy: 0.9751 - val_loss: 0.7063 - val_categorical_accuracy: 0.8000
#
# Epoch 00035: saving model to model_init_2021-02-0717_51_58.051438/model-00035-0.05958-0.97512-0.70632-0.80000.h5
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.051757735406113e-09.
# Epoch 36/50
# 67/67 [==============================] - 23s 348ms/step - loss: 0.0752 - categorical_accuracy: 0.9751 - val_loss: 0.6189 - val_categorical_accuracy: 0.8300
#
# Epoch 00036: saving model to model_init_2021-02-0717_51_58.051438/model-00036-0.07515-0.97512-0.61887-0.83000.h5
# Epoch 37/50
# 67/67 [==============================] - 25s 370ms/step - loss: 0.0840 - categorical_accuracy: 0.9652 - val_loss: 0.8270 - val_categorical_accuracy: 0.7500
#
# Epoch 00037: saving model to model_init_2021-02-0717_51_58.051438/model-00037-0.08398-0.96517-0.82695-0.75000.h5
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.5258788677030566e-09.
# Epoch 38/50
# 67/67 [==============================] - 23s 342ms/step - loss: 0.0504 - categorical_accuracy: 0.9851 - val_loss: 0.8234 - val_categorical_accuracy: 0.8000
#
# Epoch 00038: saving model to model_init_2021-02-0717_51_58.051438/model-00038-0.05040-0.98507-0.82341-0.80000.h5
# Epoch 39/50
# 67/67 [==============================] - 23s 350ms/step - loss: 0.0556 - categorical_accuracy: 0.9851 - val_loss: 0.7631 - val_categorical_accuracy: 0.7700
#
# Epoch 00039: saving model to model_init_2021-02-0717_51_58.051438/model-00039-0.05563-0.98507-0.76310-0.77000.h5
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 7.629394338515283e-10.
# Epoch 40/50
# 67/67 [==============================] - 24s 354ms/step - loss: 0.0588 - categorical_accuracy: 0.9900 - val_loss: 0.7791 - val_categorical_accuracy: 0.7500
#
# Epoch 00040: saving model to model_init_2021-02-0717_51_58.051438/model-00040-0.05883-0.99005-0.77912-0.75000.h5
# Epoch 41/50
# 67/67 [==============================] - 23s 340ms/step - loss: 0.0710 - categorical_accuracy: 0.9851 - val_loss: 0.7222 - val_categorical_accuracy: 0.7800
#
# Epoch 00041: saving model to model_init_2021-02-0717_51_58.051438/model-00041-0.07095-0.98507-0.72221-0.78000.h5
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.8146971692576415e-10.
# Epoch 42/50
# 67/67 [==============================] - 23s 350ms/step - loss: 0.0559 - categorical_accuracy: 0.9851 - val_loss: 0.8500 - val_categorical_accuracy: 0.7700
#
# Epoch 00042: saving model to model_init_2021-02-0717_51_58.051438/model-00042-0.05592-0.98507-0.85002-0.77000.h5
# Epoch 43/50
# 67/67 [==============================] - 23s 347ms/step - loss: 0.0396 - categorical_accuracy: 0.9950 - val_loss: 0.7690 - val_categorical_accuracy: 0.7800
#
# Epoch 00043: saving model to model_init_2021-02-0717_51_58.051438/model-00043-0.03955-0.99502-0.76898-0.78000.h5
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.9073485846288207e-10.
# Epoch 44/50
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0968 - categorical_accuracy: 0.9652 - val_loss: 0.6993 - val_categorical_accuracy: 0.8100
#
# Epoch 00044: saving model to model_init_2021-02-0717_51_58.051438/model-00044-0.09685-0.96517-0.69935-0.81000.h5
# Epoch 45/50
# 67/67 [==============================] - 24s 358ms/step - loss: 0.0717 - categorical_accuracy: 0.9751 - val_loss: 0.8329 - val_categorical_accuracy: 0.7800
#
# Epoch 00045: saving model to model_init_2021-02-0717_51_58.051438/model-00045-0.07173-0.97512-0.83290-0.78000.h5
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 9.536742923144104e-11.
# Epoch 46/50
# 67/67 [==============================] - 23s 347ms/step - loss: 0.0499 - categorical_accuracy: 0.9900 - val_loss: 0.8953 - val_categorical_accuracy: 0.7600
#
# Epoch 00046: saving model to model_init_2021-02-0717_51_58.051438/model-00046-0.04994-0.99005-0.89535-0.76000.h5
# Epoch 47/50
# 67/67 [==============================] - 23s 338ms/step - loss: 0.0891 - categorical_accuracy: 0.9751 - val_loss: 0.5398 - val_categorical_accuracy: 0.8000
#
# Epoch 00047: saving model to model_init_2021-02-0717_51_58.051438/model-00047-0.08912-0.97512-0.53978-0.80000.h5
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 4.768371461572052e-11.
# Epoch 48/50
# 67/67 [==============================] - 23s 343ms/step - loss: 0.0629 - categorical_accuracy: 0.9900 - val_loss: 0.8012 - val_categorical_accuracy: 0.7600
#
# Epoch 00048: saving model to model_init_2021-02-0717_51_58.051438/model-00048-0.06292-0.99005-0.80118-0.76000.h5
# Epoch 49/50
# 67/67 [==============================] - 24s 360ms/step - loss: 0.0702 - categorical_accuracy: 0.9701 - val_loss: 0.7255 - val_categorical_accuracy: 0.7900
#
# Epoch 00049: saving model to model_init_2021-02-0717_51_58.051438/model-00049-0.07023-0.97015-0.72555-0.79000.h5
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 2.384185730786026e-11.
# Epoch 50/50
# 67/67 [==============================] - 24s 360ms/step - loss: 0.0763 - categorical_accuracy: 0.9851 - val_loss: 0.8428 - val_categorical_accuracy: 0.7400
#
# Epoch 00050: saving model to model_init_2021-02-0717_51_58.051438/model-00050-0.07627-0.98507-0.84281-0.74000.h5

# %% [markdown]
# #### Model 5 CNN+LSTM

# %%
batch_size = 30
num_epochs = 15
x = 30 # # x is the number of images
y = 120 # width of the image
z = 120 # height of the image
classes = 5 #5 gestures 
channel = 3 #RGB

# %%
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.recurrent import LSTM

model_5 = Sequential()
model_5.add(TimeDistributed(Conv2D(16, (3,3), padding='same', activation='relu'),input_shape=(x,y,z,channel)))
model_5.add(TimeDistributed(BatchNormalization()))
model_5.add(TimeDistributed(MaxPooling2D((2,2))))

model_5.add(TimeDistributed(Conv2D(32, (3, 3), padding='same', activation='relu')))
model_5.add(TimeDistributed(BatchNormalization()))
model_5.add(TimeDistributed(MaxPooling2D((2, 2))))

model_5.add(TimeDistributed(Conv2D(64, (3, 3),padding='same', activation='relu')))
model_5.add(TimeDistributed(BatchNormalization()))
model_5.add(TimeDistributed(MaxPooling2D((2, 2))))

model_5.add(TimeDistributed(Conv2D(128, (3, 3), padding='same',	activation='relu')))
model_5.add(TimeDistributed(BatchNormalization()))
model_5.add(TimeDistributed(MaxPooling2D((2, 2))))

model_5.add(TimeDistributed(Conv2D(256, (3, 3), padding='same',	activation='relu')))
model_5.add(TimeDistributed(BatchNormalization()))
model_5.add(TimeDistributed(MaxPooling2D((2, 2))))

model_5.add(TimeDistributed(Flatten()))
model_5.add(LSTM(1024))

model_5.add(Dense(512,activation='relu'))
model_5.add(Dropout(0.25))

model_5.add(Dense(5, activation='softmax'))
model_5.add(Dropout(0.25))

# %%
train_generator5 = generator(train_path, train_doc, batch_size)
val_generator5 = generator(val_path, val_doc, batch_size)

optimiser = optimizers.Adam(lr=0.0002) #write your optimizer
model_5.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model_5.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_1 (TimeDist (None, 30, 120, 120, 16)  448
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 30, 120, 120, 16)  64
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 30, 60, 60, 16)    0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 30, 60, 60, 32)    4640
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 30, 60, 60, 32)    128
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 30, 30, 30, 32)    0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 30, 30, 30, 64)    18496
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 30, 30, 30, 64)    256
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 30, 15, 15, 64)    0
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 30, 15, 15, 128)   73856
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 30, 15, 15, 128)   512
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 30, 7, 7, 128)     0
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 30, 7, 7, 256)     295168
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 30, 7, 7, 256)     1024
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 30, 3, 3, 256)     0
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 30, 2304)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1024)              13635584
# _________________________________________________________________
# dense_15 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 5)                 2565
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 5)                 0
# =================================================================
# Total params: 14,557,541
# Trainable params: 14,556,549
# Non-trainable params: 992
# _________________________________________________________________
# None

# %%
history5 = model_5.fit_generator(train_generator5, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator5, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  Project_data/val ; batch size = 30
# Source path =  Project_data/train ; batch size = 30
# Epoch 1/15
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#  1/67 [..............................] - ETA: 17:06 - loss: 5.8469 - categorical_accuracy: 0.2667Batch:  4 Index: 30
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:42: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 21/67 [========>.....................] - ETA: 2:51 - loss: 1.5477 - categorical_accuracy: 0.2254Batch:  23 Index: 30
# 67/67 [==============================] - 101s 2s/step - loss: 0.4960 - categorical_accuracy: 0.2195 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.1688
#
# Epoch 00001: saving model to model_init_2021-02-0712_28_13.476088/model-00001-1.22645-0.22642-0.00000-0.16875.h5
# Epoch 2/15
# 67/67 [==============================] - 28s 415ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.2239 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.1700
#
# Epoch 00002: saving model to model_init_2021-02-0712_28_13.476088/model-00002-0.00000-0.22388-0.00000-0.17000.h5
# Epoch 3/15
# 67/67 [==============================] - 29s 436ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.2289 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.1900
#
# Epoch 00003: saving model to model_init_2021-02-0712_28_13.476088/model-00003-0.00000-0.22886-0.00000-0.19000.h5
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 4/15
# 67/67 [==============================] - 27s 399ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.1542 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.2000
#
# Epoch 00004: saving model to model_init_2021-02-0712_28_13.476088/model-00004-0.00000-0.15423-0.00000-0.20000.h5
# Epoch 5/15
# 67/67 [==============================] - 29s 429ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.2139 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.1300
#
# Epoch 00005: saving model to model_init_2021-02-0712_28_13.476088/model-00005-0.00000-0.21393-0.00000-0.13000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 6/15
# 67/67 [==============================] - 29s 435ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.1692 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.1800
#
# Epoch 00006: saving model to model_init_2021-02-0712_28_13.476088/model-00006-0.00000-0.16915-0.00000-0.18000.h5
# Epoch 7/15
# 67/67 [==============================] - 27s 399ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.2239 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.2100
#
# Epoch 00007: saving model to model_init_2021-02-0712_28_13.476088/model-00007-0.00000-0.22388-0.00000-0.21000.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 8/15
# 67/67 [==============================] - 29s 432ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.2090 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.1600
#
# Epoch 00008: saving model to model_init_2021-02-0712_28_13.476088/model-00008-0.00000-0.20896-0.00000-0.16000.h5
# Epoch 9/15
# 67/67 [==============================] - 29s 430ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.2090 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.2300
#
# Epoch 00009: saving model to model_init_2021-02-0712_28_13.476088/model-00009-0.00000-0.20896-0.00000-0.23000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 10/15
# 67/67 [==============================] - 26s 395ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.2040 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.1400
#
# Epoch 00010: saving model to model_init_2021-02-0712_28_13.476088/model-00010-0.00000-0.20398-0.00000-0.14000.h5
# Epoch 11/15
# 67/67 [==============================] - 28s 421ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.2090 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.1900
#
# Epoch 00011: saving model to model_init_2021-02-0712_28_13.476088/model-00011-0.00000-0.20896-0.00000-0.19000.h5
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 12/15
# 67/67 [==============================] - 27s 398ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.1940 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.1800
#
# Epoch 00012: saving model to model_init_2021-02-0712_28_13.476088/model-00012-0.00000-0.19403-0.00000-0.18000.h5
# Epoch 13/15
# 67/67 [==============================] - 27s 405ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.2139 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.2100
#
# Epoch 00013: saving model to model_init_2021-02-0712_28_13.476088/model-00013-0.00000-0.21393-0.00000-0.21000.h5
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 14/15
# 67/67 [==============================] - 29s 433ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.2189 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.1000
#
# Epoch 00014: saving model to model_init_2021-02-0712_28_13.476088/model-00014-0.00000-0.21891-0.00000-0.10000.h5
# Epoch 15/15
# 67/67 [==============================] - 28s 414ms/step - loss: 1.1921e-07 - categorical_accuracy: 0.1741 - val_loss: 1.1921e-07 - val_categorical_accuracy: 0.2500
#
# Epoch 00015: saving model to model_init_2021-02-0712_28_13.476088/model-00015-0.00000-0.17413-0.00000-0.25000.h5
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
